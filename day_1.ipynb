# %%
print("hola mundo")
# Out:
# hola mundo

# %%
nombre = "pablo"
ciudad = "yaguaron"
edad = 23
print(nombre,ciudad,edad)
# Out:
# pablo yaguaron 23

# %%
cantidad_de_manzanas= 4
cantidad_de_naranjas= 5
cantidad_de_frutas=cantidad_de_naranjas+cantidad_de_manzanas
print("la cantidad de frutas es:",cantidad_de_frutas)


frutas_vendidas= 5
frutas_restantes=cantidad_de_frutas-frutas_vendidas
print("la cantidad de frutas restantes es:", frutas_restantes)
# Out:
# la cantidad de frutas es: 9
# la cantidad de frutas restantes es: 4

# %%
nombre="Lucas"
apellido="Sostoa"
print(f"Hola, me llamo {nombre} {apellido}")
# Out:
# Hola, me llamo Lucas Sostoa

# %%
total_caramelos = int(input("¿Cuál es tu cantidad de caramelos?:"))
niños = int(input("¿Cuántos niños hay?: "))
caramelos_por_niño = total_caramelos // niños

print(f"Se entregaron {caramelos_por_niño} caramelos")
caramelos_sobrantes = total_caramelos - (caramelos_por_niño * niños)
print(f"Sobraron {caramelos_sobrantes} caramelos")

mal
# Out:
# Se entregaron 3 caramelos
# Sobraron 1 caramelos

# %%
def nom():
    nombre=input("ingrese su nombre:")
    edad=input("Ingrese su edad:")
    
    print(f"Mi nombres es :{nombre}")
    print(f"Mi edad es: {edad}")
nom()
nom()
nom()
# Out:
# Mi nombres es :pablo
# Mi edad es: 17
# Mi nombres es :jesus
# Mi edad es: 18
# Mi nombres es :joan 22
# Mi edad es: 14

# %% [markdown]
# Escribir una funcion que represente un sistema de pedidos de comida rapida.
# La funcion debe recibir como parametros el nombre del producto y el tamaño del pedido.
# Al ejecutarse, debe imprimir en pantalla el detalle del pedido de forma clara y ordenada.
# Luego, llamar a la funcion pasando los argumentos correspondientes para simular que un cliente realiza un pedido.

# %%
sabor_user=input("Que sabor desea:")
tamaño_user=input("Que tamaño desea")
def pedido_emp(clase,cantidad): # parametros
    print(f"El sabor es:{clase}")
    print(f"El tamaño de pedido es: {cantidad}")

pedido_emp(sabor_user,tamaño_user) # argumentos
pedido_emp(sabor_user,tamaño_user)
# Out:
# El sabor es:8}
# El tamaño de pedido es: g
# El sabor es:8}
# El tamaño de pedido es: g

# %% [markdown]
# Practicar variables globales y locales.
#
# Escribir una función calcular_total que reciba el precio de un producto y calcule el total sumando un impuesto global impuesto = 10.
# Usa una variable local total para almacenar el resultado e imprime el total.
# Llama a la función con distintos precios para probar.

# %%
precio_prod=int(input("precio producto: "))
impuesto= 10
def calcular():
    
    total= precio_prod+impuesto
    print(f"el total con impuesto es: {total}")
    
calcular()
# Out:
# el total con impuesto es: 210
